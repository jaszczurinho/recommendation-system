# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import re
import contractions
from transformers import pipeline
from concurrent.futures import ThreadPoolExecutor, as_completed
from multiprocessing import Pool, cpu_count
from tqdm import tqdm
import time

# %%
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('punkt_tab')

# %%
books_df = pd.read_excel("../output/preprocessed_books_df.xlsx")

# %%
books_df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'authors', 'average_rating', 'book_id',
#        'books_count', 'description', 'genres', 'image_url', 'language_code',
#        'original_publication_year', 'original_title', 'pages', 'publishDate',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'ratings_count', 'title', 'authors_2'],
#       dtype='object')

# %%
descriptions = books_df.description

# %% [markdown]
# The function below will help us to get an insightful look at the structure of our language corpus.

# %%
def plot_top_ngrams(texts, ngram=1, top_n=15, stop_words='english', plot=False):
    vectorizer = CountVectorizer(ngram_range=(ngram, ngram), stop_words=stop_words)
    X = vectorizer.fit_transform(texts)
    counts = X.sum(axis=0).A1
    vocab = vectorizer.get_feature_names_out()

    freq_df = pd.DataFrame({'ngram': vocab, 'count': counts})
    freq_df = freq_df.sort_values(by='count', ascending=False).head(top_n)

    if plot:
        plt.figure(figsize=(10, 6))
        plt.barh(freq_df['ngram'][::-1], freq_df['count'][::-1])
        plt.xlabel('Frequency')
        plt.ylabel(f'{ngram}-gram')
        plt.title(f'Top {top_n} {ngram}-grams')
        plt.tight_layout()
        plt.show()

    return freq_df

# %%
plot_top_ngrams(descriptions, ngram=1, top_n = 15, plot=True)
# Out:
#         ngram  count
# 25581    life   4837
# 29917     new   4572
# 48321   world   3913
# 26168    love   2893
# 41728   story   2612
# 44001    time   2493
# 26864     man   2209
# 16031  family   2172
# 5777     book   2164
# 48619   years   2057
# 30385   novel   1842
# 23781    just   1789
# 30831     old   1745
# 48713   young   1708
# 25643    like   1506

# %%
plot_top_ngrams(descriptions, ngram=2, top_n = 15, plot=True)
# Out:
#                      ngram  count
# 341002            new york   1280
# 551494            year old    772
# 553325          york times    749
# 45216   bestselling author    407
# 496220   times bestselling    399
# 44590          best friend    310
# 551769           years ago    255
# 16634      alternate cover    217
# 228538         high school    217
# 554055         young woman    216
# 33471        award winning    180
# 547621           world war    179
# 106118       cover edition    175
# 553108           york city    173
# 515194       united states    155

# %% [markdown]
# We observe that among the most common bigrams we find some that are strictly related to the advertisment of the book rathter than the plot.

# %%
plot_top_ngrams(descriptions, ngram=3, top_n = 15, plot=True)
# Out:
#                            ngram  count
# 406417            new york times    746
# 659104    york times bestselling    397
# 589295  times bestselling author    248
# 406212             new york city    172
# 18513    alternate cover edition    152
# 659081     york times bestseller    141
# 650932              world war ii     97
# 531133          sixteen year old     67
# 123277        cover edition isbn     63
# 334156  librarian note alternate     58
# 410682      note alternate cover     57
# 659080           york times best     51
# 520702        seventeen year old     50
# 464394    pulitzer prize winning     47
# 51521        best selling author     44

# %% [markdown]
# The plot of trigrams proves even more clearly, that there is a lot of noise in the descriptions, such as marketing slogans. This type of noise can lead to poor quality description embeddings. We will have to handle this.

# %% [markdown]
# Now, let's take a look at the least common words.

# %%
def rare_ngrams(texts, ngram=1, max_count=1, stop_words='english'):
    vectorizer = CountVectorizer(ngram_range=(ngram, ngram), stop_words=stop_words)
    X = vectorizer.fit_transform(texts)
    counts = X.sum(axis=0).A1
    vocab = vectorizer.get_feature_names_out()

    freq_df = pd.DataFrame({'ngram': vocab, 'count': counts})

    # Filtr rzadkich n-gramów
    rare_df = freq_df[freq_df['count'] <= max_count].sort_values('count', ascending=True)
    
    return rare_df

# %%
rare_ngrams(descriptions)
# Out:
#             ngram  count
# 0              00      1
# 2            0001      1
# 3           000th      1
# 4             001      1
# 5      0060850523      1
# ...           ...    ...
# 49219      頭上有個彈孔      1
# 49222        ﬂame      1
# 49223    ﬂavorful      1
# 49224      ﬂavors      1
# 49225         ﬂed      1
#
# [19654 rows x 2 columns]

# %% [markdown]
# So, we've got some numbers, number-like objects and even Asian characters.

# %%
def corpus_basic_stats(texts):
    lengths = [len(text.split()) for text in texts if text]

    stats = {
        'avg_description_words_num': round(np.mean(lengths),2),
        'min_description_words_num': np.min(lengths),
        'max_description_words_num': np.max(lengths)
    }

    return pd.DataFrame([stats])

# %%
corpus_basic_stats(descriptions)
# Out:
#    avg_description_words_num  min_description_words_num  \
# 0                      150.1                          1
#
#    max_description_words_num
# 0                       1068

# %% [markdown]
# The descriptions of books vary a lot. Let's take a look at the shortest ones.

# %%
def display_short_texts(df, text_col='description', title_col='title', max_words=1):
    short_df = df[df[text_col].apply(lambda x: len(str(x).split()) <= max_words)]

    return short_df[[title_col, text_col]].reset_index().copy()

# %% [markdown]
# Titles for which the length of destription is 0:

# %%
display_short_texts(books_df)
# Out:
#    index                             title  \
# 0   3465             D.Gray-man, Volume 01
# 1   6462  The Giraffe and the Pelly and Me
#
#                                          description
# 0  AKUMAとは『機械』と『魂』と『悲劇』を材料に造まれる悲しき悪性兵器。そのAKUMAを製造...
# 1                    キリンとサルとペリカン。おかしな、へんてこりんな3人ぐみだよ!

# %% [markdown]
# Descriptions containing up to 10 words:

# %%
display_short_texts(books_df, max_words=10)
# Out:
#     index                                              title  \
# 0    1747                     Kindle Paperwhite User's Guide
# 1    2985                           Nemesis (Harry Hole, #4)
# 2    3465                              D.Gray-man, Volume 01
# 3    3473  The Dark Elf Trilogy Collector's Edition (Forg...
# 4    4371                                          I Am Ozzy
# 5    4712  American on Purpose: The Improbable Adventures...
# 6    5407  Figure Drawing for All It's Worth (How to draw...
# 7    6462                   The Giraffe and the Pelly and Me
# 8    7425                                            The Egg
# 9    7750               Sleeping Beauty (Disney Princess, 5)
# 10   8097                               Three Little Kittens
# 11   8235                    Preacher, Volume 5: Dixie Fried
# 12   8563      Jamie at Home: Cook Your Way to the Good Life
#
#                                           description
# 0                      Kindle Paperwhite User's Guide
# 1   （奈斯博作品集 2） (北歐犯罪小說) (Traditional Chinese Editi...
# 2   AKUMAとは『機械』と『魂』と『悲劇』を材料に造まれる悲しき悪性兵器。そのAKUMAを製造...
# 3   Three-book set: The Dark Elf Trilogy--Homeland...
# 4                                           I Am Ozzy
# 5   American on Purpose: The Improbable Adventures...
# 6                           Hardback book. 204 pages.
# 7                     キリンとサルとペリカン。おかしな、へんてこりんな3人ぐみだよ!
# 8                   A short story about the universe.
# 9   This book tells the tale of Disney's Sleeping ...
# 10  Three little kittens lose, find, soil, and was...
# 11  Collectible. First Edition. Fifth Printing.Col...
# 12                                      Jamie at Home

# %%
lengths = books_df['description'].apply(lambda x: len(x.split()))

avg_length = lengths.mean()

plt.figure(figsize=(10,6))
plt.hist(lengths, bins=30, color='skyblue', edgecolor='black', alpha=0.7)
plt.axvline(avg_length, color='red', linestyle='dashed', linewidth=2, label=f'Average = {avg_length:.2f} words')
plt.xlabel('Number of words in description')
plt.ylabel('Number of books')
plt.title('Distribution of book description lengths')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# We decide to not proceed with the books that title is shorter than 30 characters.

# %%
books_df = books_df[books_df['description'].apply(lambda x: len(str(x).split()) >= 30)]
descriptions = books_df[['book_id', 'description']].reset_index().drop('index', axis = 1)

# %%
#display_short_texts(books_df, max_words=20)

# %%
descriptions
# Out:
#       book_id                                        description
# 0           1  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1           2  Harry Potter's life is miserable. His parents ...
# 2           3  About three things I was absolutely positive.\...
# 3           4  The unforgettable novel of a childhood in a sl...
# 4           5  Alternate Cover Edition ISBN: 0743273567 (ISBN...
# ...       ...                                                ...
# 8934     9981  A high-school girl in Harlem, Geneva Settle, i...
# 8935     9982  In Karen Marie Moning’s latest installment of ...
# 8936     9985  In the year 2000, computers are the new superp...
# 8937     9987  A CIA agent's two-year-old child was stolen in...
# 8938    10000  The First World War created the modern world. ...
#
# [8939 rows x 2 columns]

# %% [markdown]
# ## Text preparation pipeline
#
# So now that we've gathered information about the descriptions, we can proceed to preprocessing.

# %% [markdown]
# ### Important information extraction
#
# It is essential to find the best way to get the most out of descriptions in case of creating embeddings. The marketing inserts (and probably lots of more kinds of noise) were proven by the ngram analysis to play a huge part in the text, which is a bit worring, because it could potenially make our embeddings less informative.
#
# The first thing that comes to my mind is to use summarizations of preprocessed book descriptions - that could make embeddings semantically consistent and more plot-oriented. On the other hand we lose some of the details.<br>
# The second potential approach is to use some kind of keywords-extraction or keyphrases-extraction technique, so that the embedding model would get the most important words/phrases as input.

# %% [markdown]
# We will start with the first strategy - summarization. We will use a BART model that was trained on text-summary pairs dataset.

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
# Out:
# WARNING:tensorflow:From C:\Users\gabri\miniconda3\envs\venv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Device set to use cpu

# %%
def summarize_book(description, max_length=70, min_length=20):
    result = summarizer(description, max_length=max_length, min_length=min_length, do_sample=False)
    return result[0]['summary_text']

# %% [markdown]
# An example of summarized description:

# %%
summarize_book(descriptions.description[0])
# Out:
# "Sixteen-year-old Katniss Everdeen regards it as a death sentence when she steps forward to take her sister's place in the Games. Without really meaning to, she becomes a contender. But if she is to win, she will have to start making choices that weight survival against humanity and life against love."

# %% [markdown]
# The original book bescription:

# %%
descriptions.description[0]
# Out:
# "WINNING MEANS FAME AND FORTUNE.LOSING MEANS CERTAIN DEATH.THE HUNGER GAMES HAVE BEGUN. . . .In the ruins of a place once known as North America lies the nation of Panem, a shining Capitol surrounded by twelve outlying districts. The Capitol is harsh and cruel and keeps the districts in line by forcing them all to send one boy and once girl between the ages of twelve and eighteen to participate in the annual Hunger Games, a fight to the death on live TV.Sixteen-year-old Katniss Everdeen regards it as a death sentence when she steps forward to take her sister's place in the Games. But Katniss has been close to dead before—and survival, for her, is second nature. Without really meaning to, she becomes a contender. But if she is to win, she will have to start making choices that weight survival against humanity and life against love."

# %%
print(f'By applying the summarization function we have reduced the description by {len(descriptions.description[0]) - len(summary1)} characters.')
# Out:
# By applying the summarization function we have reduced the description by 540 characters.

# %%
summaries = []

for idx, desc in enumerate(tqdm(descriptions.description.to_list(), desc="Summarizing")):
    try:
        summary = summarize_book(desc)
        summaries.append(summary)
    except Exception as e:
        print(f"Błąd przy streszczaniu opisu nr {idx}: {e}")
        summaries.append(None)
# Out:
# Summarizing:   0%|▏                                                               | 31/8939 [02:19<10:38:46,  4.30s/it]Your max_length is set to 70, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Summarizing:   1%|▎                                                               | 51/8939 [03:55<11:15:36,  4.56s/it]Your max_length is set to 70, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:   1%|▍                                                                | 59/8939 [04:28<9:51:43,  4.00s/it]Your max_length is set to 70, but your input_length is only 51. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Summarizing:   1%|▌                                                               | 84/8939 [06:38<14:43:16,  5.98s/it]Your max_length is set to 70, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Summarizing:   1%|▋                                                               | 92/8939 [07:17<11:48:13,  4.80s/it]Your max_length is set to 70, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:   1%|▊                                                              | 110/8939 [08:47<12:41:35,  5.18s/it]Your max_length is set to 70, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:   1%|▊                                                              | 115/8939 [09:08<11:13:11,  4.58s/it]Your max_length is set to 70, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:   2%|█                                                               | 141/8939 [11:07<9:43:23,  3.98s/it]Your max_length is set to 70, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:   2%|█                                                               | 144/8939 [11:19<9:41:21,  3.97s/it]Your max_length is set to 70, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:   2%|█                                                              | 153/8939 [12:00<11:56:45,  4.89s/it]Your max_length is set to 70, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:   2%|█▏                                                             | 175/8939 [13:51<12:30:16,  5.14s/it]Your max_length is set to 70, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:   3%|██                                                             | 300/8939 [23:49<12:32:25,  5.23s/it]Your max_length is set to 70, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Summarizing:   3%|██▏                                                            | 310/8939 [24:32<10:41:58,  4.46s/it]Your max_length is set to 70, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Summarizing:   4%|██▌                                                            | 370/8939 [29:44<13:52:16,  5.83s/it]Your max_length is set to 70, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:   4%|██▋                                                            | 378/8939 [30:25<14:19:29,  6.02s/it]Your max_length is set to 70, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Summarizing:   5%|██▉                                                            | 420/8939 [34:21<11:12:44,  4.74s/it]Your max_length is set to 70, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:   5%|███                                                            | 429/8939 [35:01<10:31:26,  4.45s/it]Your max_length is set to 70, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:   5%|███                                                            | 441/8939 [36:00<11:06:41,  4.71s/it]Your max_length is set to 70, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Summarizing:   5%|███▏                                                            | 452/8939 [36:45<9:15:45,  3.93s/it]Your max_length is set to 70, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:   5%|███▎                                                            | 454/8939 [36:52<9:07:10,  3.87s/it]Your max_length is set to 70, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:   5%|███▏                                                           | 457/8939 [37:06<10:40:08,  4.53s/it]Your max_length is set to 70, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:   5%|███▏                                                           | 459/8939 [37:15<10:43:44,  4.55s/it]Your max_length is set to 70, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Summarizing:   5%|███▍                                                            | 476/8939 [38:31<9:43:53,  4.14s/it]Your max_length is set to 70, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:   5%|███▍                                                           | 491/8939 [39:53<12:19:06,  5.25s/it]Your max_length is set to 70, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:   6%|███▊                                                           | 543/8939 [44:06<12:11:06,  5.22s/it]Your max_length is set to 70, but your input_length is only 42. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=21)
# Summarizing:   6%|███▊                                                           | 548/8939 [44:26<10:20:50,  4.44s/it]Your max_length is set to 70, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:   6%|███▉                                                           | 566/8939 [45:53<11:41:49,  5.03s/it]Your max_length is set to 70, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:   6%|████                                                           | 577/8939 [46:51<13:46:49,  5.93s/it]Your max_length is set to 70, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Summarizing:   6%|████                                                           | 579/8939 [47:00<11:50:02,  5.10s/it]Your max_length is set to 70, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Summarizing:   7%|████▎                                                          | 616/8939 [49:57<11:25:46,  4.94s/it]Your max_length is set to 70, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Summarizing:   7%|████▌                                                          | 640/8939 [51:57<11:19:21,  4.91s/it]Your max_length is set to 70, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:   7%|████▋                                                          | 660/8939 [53:32<10:12:02,  4.44s/it]Your max_length is set to 70, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Summarizing:   9%|█████▍                                                        | 790/8939 [1:04:07<8:56:16,  3.95s/it]Your max_length is set to 70, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:   9%|█████▍                                                        | 792/8939 [1:04:15<9:28:31,  4.19s/it]Your max_length is set to 70, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:   9%|█████▋                                                       | 831/8939 [1:07:18<11:26:05,  5.08s/it]Your max_length is set to 70, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:  10%|██████▍                                                       | 936/8939 [1:16:10<9:19:17,  4.19s/it]Your max_length is set to 70, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Summarizing:  11%|██████▋                                                      | 972/8939 [1:19:13<13:05:04,  5.91s/it]Your max_length is set to 70, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:  11%|██████▊                                                      | 998/8939 [1:21:14<10:54:54,  4.95s/it]Your max_length is set to 70, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:  11%|██████▋                                                     | 1000/8939 [1:21:22<10:03:04,  4.56s/it]Your max_length is set to 70, but your input_length is only 35. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=17)
# Summarizing:  11%|██████▊                                                     | 1010/8939 [1:22:07<11:15:09,  5.11s/it]Your max_length is set to 70, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:  11%|██████▉                                                      | 1012/8939 [1:22:13<8:51:13,  4.02s/it]Your max_length is set to 70, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:  11%|██████▉                                                     | 1025/8939 [1:23:16<11:14:27,  5.11s/it]Your max_length is set to 70, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Summarizing:  12%|███████▎                                                    | 1084/8939 [1:27:57<10:15:23,  4.70s/it]Your max_length is set to 70, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:  12%|███████▌                                                     | 1114/8939 [1:30:07<9:15:20,  4.26s/it]Your max_length is set to 70, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:  13%|███████▌                                                    | 1119/8939 [1:30:33<11:15:17,  5.18s/it]Your max_length is set to 70, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  13%|███████▌                                                    | 1125/8939 [1:30:58<10:05:14,  4.65s/it]Your max_length is set to 70, but your input_length is only 39. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=19)
# Summarizing:  13%|███████▌                                                    | 1132/8939 [1:31:31<10:52:23,  5.01s/it]Your max_length is set to 70, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  13%|███████▋                                                    | 1146/8939 [1:32:37<10:33:44,  4.88s/it]Your max_length is set to 70, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:  13%|███████▉                                                     | 1160/8939 [1:33:41<8:44:42,  4.05s/it]Your max_length is set to 70, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Summarizing:  13%|███████▉                                                     | 1170/8939 [1:34:25<8:48:22,  4.08s/it]Your max_length is set to 70, but your input_length is only 46. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Summarizing:  13%|███████▉                                                    | 1186/8939 [1:35:34<11:17:07,  5.24s/it]Your max_length is set to 70, but your input_length is only 45. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing:  13%|███████▉                                                    | 1189/8939 [1:35:48<10:47:46,  5.02s/it]Your max_length is set to 70, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  13%|████████                                                    | 1195/8939 [1:36:17<10:28:39,  4.87s/it]Your max_length is set to 70, but your input_length is only 68. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Summarizing
/it]Your max_length is set to 70, but your input_length is only 67. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:  22%|█████████████▎                                               | 1954/8939 [2:38:54<8:33:25,  4.41s/it]Your max_length is set to 70, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:  22%|█████████████▍                                              | 2000/8939 [2:42:42<11:04:21,  5.74s/it]Your max_length is set to 70, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Summarizing:  22%|█████████████▋                                               | 2003/8939 [2:42:55<9:02:47,  4.70s/it]Your max_length is set to 70, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:  23%|█████████████▌                                              | 2012/8939 [2:43:44<10:14:53,  5.33s/it]Your max_length is set to 70, but your input_length is only 36. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=18)
# Summarizing:  23%|█████████████▊                                               | 2028/8939 [2:45:07<9:21:38,  4.88s/it]Your max_length is set to 70, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:  23%|█████████████▊                                              | 2053/8939 [2:47:03<11:28:50,  6.00s/it]Your max_length is set to 70, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:  24%|██████████████                                              | 2102/8939 [2:51:04<10:36:36,  5.59s/it]Your max_length is set to 70, but your input_length is only 66. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=33)
# Summarizing:  24%|██████████████▋                                              | 2156/8939 [2:55:23<8:49:53,  4.69s/it]Your max_length is set to 70, but your input_length is only 61. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Summarizing:  25%|███████████████                                              | 2204/8939 [2:59:42<9:34:00,  5.11s/it]Your max_length is set to 70, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:  25%|███████████████                                              | 2205/8939 [2:59:46<8:52:38,  4.75s/it]Your max_length is set to 70, but your input_length is only 55. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:  26%|███████████████▊                                             | 2318/8939 [3:08:41<8:56:30,  4.86s/it]Your max_length is set to 70, but your input_length is only 51. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Summarizing:  26%|████████████████                                             | 2361/8939 [3:12:15<9:49:41,  5.38s/it]Your max_length is set to 70, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:  28%|█████████████████▏                                           | 2516/8939 [3:24:39<8:50:32,  4.96s/it]Your max_length is set to 70, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Summarizing:  28%|█████████████████▎                                           | 2538/8939 [3:26:25<8:37:00,  4.85s/it]Your max_length is set to 70, but your input_length is only 69. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=34)
# Summarizing:  28%|█████████████████▎                                           | 2539/8939 [3:26:30<8:20:48,  4.70s/it]Your max_length is set to 70, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  28%|█████████████████▎                                           | 2543/8939 [3:26:48<8:44:43,  4.92s/it]Your max_length is set to 70, but your input_length is only 48. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=24)
# Summarizing:  29%|█████████████████▊                                           | 2604/8939 [3:31:48<8:26:16,  4.80s/it]Your max_length is set to 70, but your input_length is only 50. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=25)
# Summarizing:  29%|█████████████████▌                                          | 2610/8939 [3:32:21<10:35:28,  6.02s/it]Your max_length is set to 70, but your input_length is only 54. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=27)
# Summarizing:  29%|█████████████████▉                                           | 2625/8939 [3:33:33<7:47:10,  4.44s/it]Your max_length is set to 70, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Summarizing:  30%|██████████████████                                           | 2641/8939 [3:34:53<7:50:32,  4.48s/it]Your max_length is set to 70, but your input_length is only 62. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Summarizing:  30%|██████████████████▏                                          | 2665/8939 [3:36:58<9:32:31,  5.48s/it]Your max_length is set to 70, but your input_length is only 59. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  30%|██████████████████▏                                          | 2671/8939 [3:37:24<7:40:40,  4.41s/it]Your max_length is set to 70, but your input_length is only 41. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Summarizing:  30%|██████████████████▎                                          | 2683/8939 [3:38:22<9:05:32,  5.23s/it]Your max_length is set to 70, but your input_length is only 53. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:  30%|██████████████████▎                                          | 2684/8939 [3:38:24<7:33:07,  4.35s/it]Your max_length is set to 70, but your input_length is only 56. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:  30%|██████████████████▍                                          | 2706/8939 [3:40:13<9:07:11,  5.27s/it]Your max_length is set to 70, but your input_length is only 63. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=31)
# Summarizing:  30%|██████████████████▍                                          | 2710/8939 [3:40:34<9:20:45,  5.40s/it]Your max_length is set to 70, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  30%|██████████████████▌                                          | 2720/8939 [3:41:21<7:31:10,  4.35s/it]Your max_length is set to 70, but your input_length is only 57. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=28)
# Summarizing:  31%|██████████████████▊                                          | 2755/8939 [3:44:08<8:34:53,  5.00s/it]Your max_length is set to 70, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  31%|███████████████████                                          | 2802/8939 [3:47:55<8:03:53,  4.73s/it]Your max_length is set to 70, but your input_length is only 40. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=20)
# Summariz
/it]Your max_length is set to 70, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Summarizing:  98%|████████████████████████████████████████████████████████████▉ | 8786/8939 [11:59:19<11:41,  4.58s/it]Your max_length is set to 70, but your input_length is only 58. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=29)
# Summarizing:  98%|████████████████████████████████████████████████████████████▉ | 8789/8939 [11:59:33<12:12,  4.88s/it]Your max_length is set to 70, but your input_length is only 47. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=23)
# Summarizing:  98%|█████████████████████████████████████████████████████████████ | 8803/8939 [12:00:46<12:06,  5.34s/it]Your max_length is set to 70, but your input_length is only 65. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:  99%|█████████████████████████████████████████████████████████████▎| 8838/8939 [12:03:35<07:47,  4.63s/it]Your max_length is set to 70, but your input_length is only 52. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=26)
# Summarizing:  99%|█████████████████████████████████████████████████████████████▎| 8848/8939 [12:04:26<07:46,  5.12s/it]Your max_length is set to 70, but your input_length is only 60. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=30)
# Summarizing:  99%|█████████████████████████████████████████████████████████████▍| 8860/8939 [12:05:25<06:44,  5.12s/it]Your max_length is set to 70, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing:  99%|█████████████████████████████████████████████████████████████▍| 8861/8939 [12:05:29<06:09,  4.74s/it]Your max_length is set to 70, but your input_length is only 64. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=32)
# Summarizing: 100%|█████████████████████████████████████████████████████████████▋| 8900/8939 [12:08:28<03:05,  4.74s/it]Your max_length is set to 70, but your input_length is only 44. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=22)
# Summarizing: 100%|██████████████████████████████████████████████████████████████| 8939/8939 [12:39:18<00:00,  5.10s/it]

# %%
descriptions["summaries"] = summaries

# %% [markdown]
# ### Data cleaning

# %% [markdown]
# We perform following preprocessing steps:
# - converting words to lowercase
# - white spaces cleaning
# - non-alpha characters removal (just in case)
# - stop-words cleaning

# %%
def clean_text(input_text):    
    # clean_text = re.sub('<[^<]+?>', '', input_text)  
    # clean_text = re.sub(r'http\S+', '', clean_text)
    
    clean_text = input_text.lower()
    clean_text = re.sub('\s+', ' ', clean_text)
    clean_text = re.sub('[^a-zA-Z\s]', '', clean_text)
    
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(clean_text)
    tokens = [token for token in tokens if token not in stop_words]
    clean_text = ' '.join(tokens)

    return clean_text

# %% [markdown]
# Turns out that the model didn't summarize one of the descriptions - let's drop it.

# %%
descriptions[descriptions.summaries.isna()]
# Out:
#       book_id                                        description summaries
# 3321     3831  More About DaveA Man Named Dave is the conclus...      None

# %%
descriptions = descriptions.dropna()

# %%
descriptions["preprocessed_summarization"] = descriptions["summaries"].apply(clean_text)
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_3808\1903643063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   descriptions["preprocessed_summarization"] = descriptions["summaries"].apply(clean_text)

# %% [markdown]
# Example of description after applying the preprocessing function:

# %%
descriptions.preprocessed_summarization[0]
# Out:
# 'sixteenyearold katniss everdeen regards death sentence steps forward take sisters place games without really meaning becomes contender win start making choices weight survival humanity life love'

# %% [markdown]
# The summarized version:

# %%
descriptions.summaries[0]
# Out:
# "Sixteen-year-old Katniss Everdeen regards it as a death sentence when she steps forward to take her sister's place in the Games. Without really meaning to, she becomes a contender. But if she is to win, she will have to start making choices that weight survival against humanity and life against love."

# %% [markdown]
# New corpus stats:

# %%
corpus_basic_stats(descriptions.preprocessed_summarization)
# Out:
#    avg_description_words_num  min_description_words_num  \
# 0                      22.14                          5
#
#    max_description_words_num
# 0                         40

# %%
descriptions.to_excel('summrized_preprocessed_descriptions.xlsx')
