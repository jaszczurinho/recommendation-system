# %% [markdown]
# This notebook is the primary step to build my first ever recommendation system. The data that will be fed into the system is an extended version of the original <a href=https://github.com/zygmuntz/goodbooks-10k>goodbooks-10k</a> dataset made by <a href="https://github.com/zygmuntz">@Zygmunt Zając</a>, whereas the extended one (enriched with e.g.: book descriptions, genres. More info about the additional fields <a href="https://github.com/malcolmosh/goodbooks-10k-extended/blob/master/README.md">here</a>) was made by user <a href="https://github.com/malcolmosh">malcolmosh</a>. Big shoutout to them both!<br>

# %% [markdown]
# The main idea of the system is to print out the recommendations based on the user's query. So that will include text preprocessing, creating text embeddings, calculation of vector similarity scores based on which the retrieval will retirive top-n recommendations.  <br>

# %% [markdown]
# But before all of that let's start with EDA.

# %%
import pandas as pd
from ast import literal_eval
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# %%
books_df= pd.read_csv('https://raw.githubusercontent.com/malcolmosh/goodbooks-10k/master/books_enriched.csv', index_col=[0], converters={"genres": literal_eval})

# %% [markdown]
# Let's remove the columns that we won't need. Also, for the purposes of this exercise, we will only select books published in English.

# %%
books_df= books_df.drop(['best_book_id', 'goodreads_book_id', 'isbn', 'isbn13', 'small_image_url', 'work_id'], axis=1)
books_df= books_df[books_df["language_code"] == "eng"]

# %%
books_df.isna().sum()
# Out:
# index                          0
# authors                        0
# average_rating                 0
# book_id                        0
# books_count                    0
# description                   52
# genres                         0
# image_url                      0
# language_code                  0
# original_publication_year     20
# original_title               562
# pages                         69
# publishDate                    8
# ratings_1                      0
# ratings_2                      0
# ratings_3                      0
# ratings_4                      0
# ratings_5                      0
# ratings_count                  0
# title                          0
# work_ratings_count             0
# work_text_reviews_count        0
# authors_2                      0
# dtype: int64

# %% [markdown]
# Let's investigate the columns with missing values.

# %%
def print_n(data, n):
    return data.head(n)

# %%
print_n(books_df["title"], 10)
# Out:
# 0              The Hunger Games (The Hunger Games, #1)
# 1    Harry Potter and the Sorcerer's Stone (Harry P...
# 2                              Twilight (Twilight, #1)
# 3                                To Kill a Mockingbird
# 4                                     The Great Gatsby
# 5                               The Fault in Our Stars
# 6                                           The Hobbit
# 7                               The Catcher in the Rye
# 8                Angels & Demons  (Robert Langdon, #1)
# 9                                  Pride and Prejudice
# Name: title, dtype: object

# %%
print_n(books_df["original_title"], 10)
# Out:
# 0                            The Hunger Games
# 1    Harry Potter and the Philosopher's Stone
# 2                                    Twilight
# 3                       To Kill a Mockingbird
# 4                            The Great Gatsby
# 5                      The Fault in Our Stars
# 6          The Hobbit or There and Back Again
# 7                      The Catcher in the Rye
# 8                            Angels & Demons
# 9                         Pride and Prejudice
# Name: original_title, dtype: object

# %% [markdown]
# Given that the titles in the `original_title` columns are easier to use (the `title` variable contains additional info about the series of book, which won't be needed), we'll have to get rid of rows missing this value.

# %% [markdown]
# Books for which we do not have descriptions are unnecessary, since the descriptions will be really important to base the recommendations on.

# %%
print_n(books_df[books_df["description"].isna()], 5)
# Out:
#       index                                        authors  average_rating  \
# 427     427                                  ['Anonymous']            4.43
# 911     911                                ['Jules Verne']            3.84
# 1044   1044       ['Aesop', 'Laura Harris', 'Laura Gibbs']            4.05
# 1244   1244  ['Allen Ginsberg', 'William Carlos Williams']            4.14
# 1252   1252              ['Anonymous', 'Joseph Smith Jr.']            4.37
#
#       book_id  books_count description  \
# 427       464         1449         NaN
# 911       972         1363         NaN
# 1044     1120          942         NaN
# 1244     1329           47         NaN
# 1252     1338          343         NaN
#
#                                                  genres  \
# 427   [religion, classics, nonfiction, christian, hi...
# 911       [classics, science-fiction, fiction, fantasy]
# 1044           [classics, fiction, fantasy, philosophy]
# ...

# %%
books_df= books_df[books_df["original_title"].notna() & books_df["description"].notna() & books_df["original_publication_year"].notna()]

# %% [markdown]
# The other columns containing missing values are not as relevant to our tasks, so we will ignore them.

# %%
#books_df.to_excel("./output/preprocessed_books.xlsx")

# %% [markdown]
# ## Per author analysis

# %% [markdown]
# Let us examine the authors' analysis. This step is necessary because we will have to somehow take into account the authors' *popularity* in the recommendation system, since, on the one hand, books by good writers are theoretically better than books by less talented artists, but we cannot favour them too much.

# %%
authors_books_df = books_df[['authors', 'average_rating', 'work_ratings_count', 'book_id']].copy()
authors_books_df['authors'] = authors_books_df['authors'].str.split(',')
authors_exploded = authors_books_df.explode('authors')
authors_exploded['authors'] = authors_exploded['authors'].str.strip().replace(r"[\[\]']", "", regex=True)

# %%
author_stats = authors_exploded.groupby('authors').agg({
    'book_id': 'count',                
    'average_rating': ['mean', 'std'], 
    'work_ratings_count': 'sum'        
})

author_stats.columns = ['book_count', 'avg_rating', 'rating_std', 'total_ratings']

# %%
active_authors = author_stats[author_stats["book_count"] > 5]

# %%
active_authors.drop("rating_std", axis = 1).describe()
# Out:
#        book_count  avg_rating  total_ratings
# count  401.000000  401.000000   4.010000e+02
# mean    11.730673    4.028203   8.938425e+05
# std      9.152174    0.200795   1.645930e+06
# min      6.000000    3.086667   7.732500e+04
# 25%      7.000000    3.891500   2.379720e+05
# 50%      9.000000    4.032857   4.252490e+05
# 75%     13.000000    4.180714   8.389200e+05
# max     91.000000    4.703077   1.819044e+07

# %% [markdown]
# The table below presents authors sorted in descending order by the number of total ratings of their books.

# %%
 active_authors.sort_values('total_ratings', ascending=False).head(15)
# Out:
#                      book_count  avg_rating  rating_std  total_ratings
# authors
# J.K. Rowling                 23    4.250000    0.360669       18190437
# Mary GrandPré                 8    4.517500    0.093159       16062742
# Stephen King                 87    3.987126    0.301754        9162340
# Suzanne Collins               9    4.220000    0.152725        9161124
# Stephenie Meyer              13    3.803077    0.243392        8729417
# J.R.R. Tolkien               13    4.210000    0.278927        6198500
# Rick Riordan                 26    4.300000    0.186826        5785002
# Dan Brown                     6    3.728333    0.098268        5313824
# Cassandra Clare              15    4.322000    0.202386        4721157
# John Green                    6    3.923333    0.220424        4643411
# William Shakespeare          20    3.891500    0.222125        4622559
# Nicholas Sparks              20    4.007500    0.120301        4535781
# ...

# %% [markdown]
# We observe, that despite of having the biggest total number of book ratings *J.K. Rowling* doesn't have the highest average rating, which indicates that mass appeal attracts a broader audience with diverse tastes, often leading to more polarized reviews compared to niche authors.

# %%
active_authors.sort_values('avg_rating', ascending=False).head(15)
# Out:
#                    book_count  avg_rating  rating_std  total_ratings
# authors
# Bill Watterson             13    4.703077    0.056478         448543
# Mary GrandPré               8    4.517500    0.093159       16062742
# Fiona Staples               6    4.463333    0.116218         329921
# Sarah J. Maas              13    4.453077    0.146366        1368714
# Todd Klein                 10    4.416000    0.197833         493908
# Natsuki Takaya              7    4.380000    0.077889         207762
# Athena Nibley               7    4.380000    0.077889         207762
# Alethea Nibley              7    4.380000    0.077889         207762
# Tsugumi Ohba                7    4.378571    0.054598         246546
# Takeshi Obata               7    4.378571    0.054598         246546
# Gabriel Rodríguez           7    4.371429    0.130439         162786
# Karen Kingsbury            10    4.369000    0.086980         144824
# ...

# %% [markdown]
# We note a rather interesting case in which some authors have a large number of reviews, e.g., *Mary GrandPré* or *Sarah J. Maas* and yet still receive one of the best average ratings. Apart from those exceptions, the best-rated authors are not read very often, which confirms the previously stated thesis that as the number of reviews of authors' works increases, it becomes much more difficult for him to achieve good statistics.

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(
    data=active_authors, 
    x='book_count', 
    y='avg_rating', 
    size='total_ratings', 
    sizes=(20, 500), 
    alpha=0.6,
    hue='avg_rating',
    palette='viridis'
)
plt.xlabel("Number of written books")
plt.ylabel("Average rating of author")
plt.show()

# %% [markdown]
# Most of the authors have written significantly less than 20 books (as shown before, the median of written books is equal to 9), the biggest group of best reviewed authors (the lime green dot) wrote around 6-7 books.The mode of number of written books is:

# %%
int(active_authors.mode().iloc[0, 0])
# Out:
# 6

# %% [markdown]
# ## Per book analysis

# %%
genre_counts = books_df["genres"].explode().value_counts()

# %%
plt.figure(figsize=(10, 8))

ax = sns.barplot(
    x=genre_counts.values, 
    y=genre_counts.index, 
    palette='viridis',
    hue = genre_counts.index
)
plt.title('Frequency histogram of book genres')
plt.xlabel('Frequency')
plt.ylabel('Genre')

for i, v in enumerate(genre_counts.values):
    ax.text(v + 35, i + 0.4, str(v), color='black')

plt.tight_layout()
plt.show()

# %%
print(f'We\'ve got total of {genre_counts.shape[0]} different genres of books.')
# Out:
# We've got total of 39 different genres of books.

# %% [markdown]
# This variable will play a key role in the recommendation process, because on the one hand, the user may potentially want to read only a specific type of book, and on the other hand, they will be able to exclude books of a certain genre.
#
# The `genres` variable will be one of the first filters used to reduce the full data set to a certain subset, based on the book genres specified by the user. The same methodology applies to the `authors` variable value.

# %% [markdown]
# One of the future challenges we will have to face is the problem that a user may specify a book genre (although this will also apply to other variables that we extract from the user's query) that is not included in the given list of book genres. In this case, we will have to develop a system for assigning the closest (semantically) predefined values.

# %% [markdown]
# Let's now look at the statistics on book ratings.

# %%
mean_rating = books_df['average_rating'].mean()
median_rating = books_df['average_rating'].median()

plt.figure(figsize=(10, 6))
sns.histplot(books_df['average_rating'], bins=45, kde=True, color='coral')

plt.axvline(mean_rating, color='red', linestyle='--', label=f'Mean: {mean_rating:.2f}')
plt.axvline(median_rating, color='blue', linestyle='-.', label=f'Median: {median_rating:.2f}')

plt.title('Distribution of average rating',fontweight='bold')
plt.xlabel('Average book rating')
plt.ylabel('Quantity')
plt.legend()

plt.show()

# %% [markdown]
# The average book ratings are distributed roughly symmetrically, with the median being almost equal to the mean. The density distribution approximates a bell curve, though it exhibits a slight negative skew, which means, that very low ratings are more frequent and more dispersed than very high ratings, reflecting the tendency of users to give books positive ratings in most cases.

# %%
books_df["genres"].explode().drop_duplicates().reset_index(drop=True).tolist()
# Out:
# ['young-adult',
#  'fiction',
#  'fantasy',
#  'science-fiction',
#  'romance',
#  'classics',
#  'paranormal',
#  'historical-fiction',
#  'contemporary',
#  'mystery',
#  'thriller',
#  'suspense',
#  'crime',
#  'nonfiction',
#  'history',
#  'biography',
#  'memoir',
#  'poetry',
#  'chick-lit',
#  'christian',
#  'travel',
#  'spirituality',
#  'philosophy',
#  'psychology',
#  'horror',
#  'business',
#  'science',
#  'religion',
#  'self-help',
#  'art',
#  'music',
#  'graphic-novels',
#  'comics',
#  'sports',
#  'manga',
#  'cookbooks',
#  'books',
#  'humor-and-comedy',
#  'gay-and-lesbian']
